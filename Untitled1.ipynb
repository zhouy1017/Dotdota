# %%
# !pip install dota2api
import dota2api
import numpy as np
import pandas as pd
import requests
api = dota2api.Initialise()

# %%
team_id = 5
postion = -1
win = 0
match = api.get_match_details(match_id=3175065918)
info = []
if match['radiant_team_id'] == 5:
    position = 0
else:
    position = 5
if match['radiant_win']:
    if position == 0:
        win = 1
    else:
        win = 0
else:
    if position == 0:
        win = 0
    else:
        win = 1
match
# Out:
# {'barracks_status_dire': 63,
#  'barracks_status_radiant': 63,
#  'cluster': 224,
#  'cluster_name': 'China',
#  'dire_captain': 98878010,
#  'dire_logo': 186170815315920305,
#  'dire_name': 'LGD-GAMING',
#  'dire_score': 26,
#  'dire_team_complete': 1,
#  'dire_team_id': 15,
#  'duration': 1607,
#  'engine': 1,
#  'first_blood_time': 54,
#  'flags': 1,
#  'game_mode': 2,
#  'game_mode_name': 'Captains Mode',
#  'human_players': 10,
#  'leagueid': 4442,
#  'lobby_name': 'Practice',
#  'lobby_type': 1,
#  'match_id': 3175065918,
#  'match_seq_num': 2773182878,
#  'negative_votes': 26,
#  'picks_bans': [{'hero_id': 32, 'is_pick': False, 'order': 0, 'team': 1},
#   {'hero_id': 83, 'is_pick': False, 'order': 1, 'team': 0},
#   {'hero_id': 114, 'is_pick': False, 'order': 2, 'team': 1},
#   {'hero_id': 88, 'is_pick': False, 'order': 3, 'team': 0},
#   {'hero_id': 37, 'is_pick': True, 'order': 4, 'team': 1},
#   {'hero_id': 28, 'is_pick': True, 'order': 5, 'team': 0},
# ...

# %%
def get_match_detail(lst):
    return []

# %%
a = requests.get()
# Out:
# [{'name': 'Rainbow', 'tag': 'Rainbow', 'team_id': 2777181},
#  {'name': 'The Price is Reich', 'tag': 'TPIR', 'team_id': 2570049},
#  {'name': 'QO diciples', 'tag': 'QO', 'team_id': 4361011},
#  {'name': 'Guess Jeans', 'tag': 'Guess', 'team_id': 2041520},
#  {'name': 'YES8Return', 'tag': 'YES8', 'team_id': 1408765},
#  {'name': 'Sick.Gaming', 'tag': 'Sick', 'team_id': 1067849},
#  {'name': 'Revolution E-sports ', 'tag': '', 'team_id': 4258196},
#  {'name': 'Death_Squad', 'tag': 'DS', 'team_id': 1960261},
#  {'name': 'Team Buriza', 'tag': 'TB', 'team_id': 3927252},
#  {'name': 'D - Gaming', 'tag': "D'G", 'team_id': 1837146},
#  {'name': 'TEAM  Koala Net', 'tag': '[KN]', 'team_id': 2886195},
#  {'name': 'Black Mobster', 'tag': 'BM', 'team_id': 2227154},
#  {'name': 'Full survival', 'tag': 'FS', 'team_id': 963631},
#  {'name': 'Team Tralalala', 'tag': 'Tralala', 'team_id': 951431},
#  {'name': 'The Sabotage^^', 'tag': 'Sabotage', 'team_id': 2633332},
# ...
